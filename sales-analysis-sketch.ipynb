# %%
import pandas as pd
import requests
import csv
import datetime 
import locale
import time
locale.setlocale(locale.LC_ALL, 'en_US')
# Out:
# 'en_US'

# %%
id_event_bolafy = pd.read_csv('id_event_bolafy.csv')
id_event_bolafy_list = list(id_event_bolafy['id_event'])

# %%
id_event_non_bolafy = pd.read_csv('id_event_non_bolafy.csv')
id_event_non_bolafy_list = list(id_event_non_bolafy['id_event'])

# %%
def get_table(table_name=''):
    """
    Returns pandas dataframe

    table_name options:

    transactions
    users
    tickets
    nft
    moflip_ticket
    """ 
    x = requests.get(f"https://api.tiketnft.com/table/export?table_name={table_name}&token=B1m4j3nie")
    text = x.text

    lines = text.splitlines()
    reader = csv.reader(lines)
    parsed_csv = list(reader)

    df = pd.DataFrame(parsed_csv[1:], columns=parsed_csv[0])
    
    return df.dropna()

# %%
id_event_non_bolafy_list
# Out:
# [74371, 75951, 75956, 75957, 75958, 75959]

# %%
def get_all_bolafy_trx():
    transactions_df = get_table('transactions')

    transactions_df.drop(transactions_df.index[transactions_df['invoice_payment_total'] == 'null'], inplace=True)
    transactions_df.drop(transactions_df.index[transactions_df['user_id'] == 'null'], inplace=True)


    transactions_df = transactions_df.astype(
            {
                "id_event":"int", 
                "invoice_payment_total": "int",
                "settlement_paid_timestamp": "datetime64[ns]"
            })

    transactions_df = transactions_df[transactions_df.invoice_payment_total != 0]

    bolafy_filter = ~transactions_df['id_event'].isin(id_event_non_bolafy_list)

    return transactions_df[bolafy_filter]

def get_bolafy_trx_by_event(event_ids=[]):
    all_bolafy_trx = get_all_bolafy_trx()

    if len(event_ids) == 0:
        return all_bolafy_trx


    event_filter = all_bolafy_trx['id_event'].isin(event_ids)

    return all_bolafy_trx[event_filter]

def get_bolafy_trx_by_date(all_trx, date='today', range = (1,0), format_date='%m-%d-%Y %H:%M:%S'):

    """
    date    : today, yesterday
    range   : (day,hour)

    """

    if date == 'today':
        date_explore = pd.to_datetime(datetime.datetime.today().strftime(format_date)).floor('D')
    elif date == 'yesterday':
        date_explore = pd.to_datetime(datetime.datetime.today() - datetime.timedelta(days=1)).floor('D')
        
    else: 
        date_explore = pd.to_datetime(datetime.datetime.strptime(date, format_date))

    mask = ((all_trx['settlement_paid_timestamp'] >= date_explore) & (all_trx['settlement_paid_timestamp'] < (date_explore + pd.Timedelta(days=range[0], seconds=range[1] * 3600))))
    df = all_trx.loc[mask]

    return df

def print_rupiah(num):
    return f'Rp {locale.currency(num, grouping=True)[1:]}'

def get_sales_by_event(trx=''):
    """
    trx: transaction dataframe
    """

    sales_by_id_event = trx.groupby('id_event').sum('id_event')
    all_id_event = list(sales_by_id_event.index)
    sales_by_id_event = sales_by_id_event.to_dict()

    # Load moflip ticket table and 
    moflip_ticket_table = get_table('moflip_ticket').astype({
        'event_id':'int'
    })
    mask = (moflip_ticket_table['event_id'].isin(all_id_event))
    moflip_ticket_table = moflip_ticket_table.loc[mask]

    gk = moflip_ticket_table.groupby('event_id') # Group by event id
    event_id_name = gk.first()['description'].to_dict()

    event_name_sales_dict = {}

    print(sales_by_id_event)

    for id_event in all_id_event:
       event_name_sales_dict[event_id_name[id_event]] = (sales_by_id_event['invoice_payment_total'][id_event])

    return event_name_sales_dict



def get_total_sales(trx=''):
    """
    trx: transaction dataframe

    """

    total_transaction = trx['invoice_payment_total'].sum()
    total_transaction_rupiah = print_rupiah(total_transaction)

    return total_transaction, total_transaction_rupiah

def get_num_transaction(all_trx, date='07-18-2000 00:00:00', format_date='%m-%d-%Y %H:%M:%S'):

    date_object = pd.to_datetime(datetime.datetime.strptime(date, format_date))

    mask = (all_trx['settlement_paid_timestamp'] >= date_object)
    
    return len(all_trx[mask])

# Utils function
def _get_change_percentage(a,b):

    percentage_change = 0

    try:
        percentage_change = float((b-a)/a) * 100 
    except ZeroDivisionError:
        pass

    sign = '🍀' if percentage_change > 0 else '🔻'
    
    return sign, percentage_change

# %%
from datetime import timedelta


def generate_today_sales_report(date='today', week_start_date='09-12-2022 00:00:00', format_date='%m-%d-%Y %H:%M:%S', event_ids=[], title=''):

    """ Improvements : 

    Harus ada generalize generate sales report from x time till x time

    Function ini sementara
    """

    cur_time = datetime.datetime.now()

    today_str = (cur_time).strftime(format_date)
    firstDayOfMonth = datetime.date(cur_time.year, cur_time.month, 1).strftime(format_date)
    
    # All Time
    all_trx = get_bolafy_trx_by_event(event_ids)

    # Today
    today_sales = get_bolafy_trx_by_date(all_trx, date)
    today_sales_amt = get_total_sales(today_sales)

    # Yesterday
    yesterday_sales = get_bolafy_trx_by_date(all_trx, 'yesterday')
    yesterday_sales_amt = get_total_sales(yesterday_sales)

    # This Week
    this_week_sales = get_bolafy_trx_by_date(all_trx, week_start_date, range=(7,0))
    this_week_sales_amt = get_total_sales(this_week_sales)

    # Last Week
    last_week_sales = get_bolafy_trx_by_date(all_trx, (datetime.datetime.strptime(week_start_date, format_date) - timedelta(days=7)).strftime(format_date), range=(7,0))
    last_week_sales_amt = get_total_sales(last_week_sales)

    # Last Month
    this_month_sales = get_bolafy_trx_by_date(all_trx, '09-01-2022 00:00:00', range=(30,0))
    this_month_sales_amt = get_total_sales(this_month_sales)    

    percentage_change = _get_change_percentage(yesterday_sales_amt[0], today_sales_amt[0])
    percentage_change_str = f"{'{0:.2f}'.format(percentage_change[1])}%"

    num_trx_all_time = get_num_transaction(all_trx)
    num_trx_month = get_num_transaction(all_trx, firstDayOfMonth)

    SALES_REPORT = f"""
    
    _🤖 Automated Message_ 

    *Bolafy Sales Report 🛒 - {title}*

    Today's Sale: {today_sales_amt[1]}

    Change from yesterday: {percentage_change[0]} {percentage_change_str}

    --- 💰 Sales --- 

    Yesterday Sales: {yesterday_sales_amt[1]}
    Last week sales: {last_week_sales_amt[1]}
    This week sales: {this_week_sales_amt[1]} (so far)
    This month sales: {this_month_sales_amt[1]} (so far)
    

    --- 🧧 Transactions ---

    Monthly Transaction: {num_trx_month}
    All Time Transaction: {num_trx_all_time}


    _Updated: {today_str}_

    """


    return str(SALES_REPORT)

# %%
print(generate_today_sales_report('today', week_start_date='09-19-2022 00:00:00', event_ids=[82424], title='Ismed Sofyan Campaign'))
# Out:
#
#     _🤖 Automated Message_
#
#     *Bolafy Sales Report 🛒 - Ismed Sofyan Campaign*
#
#     Today's Sale: Rp 0.00
#
#     Change from yesterday: 🔻 -100.00%
#
#     --- 💰 Sales ---
#
#     Yesterday Sales: Rp 289,275.00
#     Last week sales: Rp 5,483,376.00
#     This week sales: Rp 3,104,275.00 (so far)
#     This month sales: Rp 8,587,651.00 (so far)
#
#
#     --- 🧧 Transactions ---
#
#     Monthly Transaction: 10
#     All Time Transaction: 10
#
#
#     _Updated: 09-23-2022 09:37:38_

# %%
all_trx = get_bolafy_trx_by_event(event_ids=[82424])

# %%
this_month_sales = get_bolafy_trx_by_date(all_trx, '09-01-2022 00:00:00', range=(30,0))
this_month_sales_amt = get_total_sales(this_month_sales)

# %%
this_month_sales_amt
# Out:
# (8587651, 'Rp 8,587,651.00')

# %%
all_trx.head()
# Out:
#         id user_id          id_order  \
# 8994  9011   12519  82424SEPXLUDWMQX
# 8995  9012   12519  82424SEPXLUD8BUB
# 8996  9013   12519  82424SEPXLUCJCQJ
# 8997  9014   12412  82424SEPXLUAIRCT
# 8999  9016   11968  82424SEPXLUGXBIH
#
#                                            evoucher_url  \
# 8994  https://neo.loket.com/evoucher/36896ba6-261a-4...
# 8995  https://neo.loket.com/evoucher/b43e5bea-8192-4...
# 8996  https://neo.loket.com/evoucher/59163cf6-0367-4...
# 8997  https://neo.loket.com/evoucher/9bf85933-b6dc-4...
# 8999  https://neo.loket.com/evoucher/5bb1ea99-71d0-4...
#
#                                    eticket_url invoice_code  \
# 8994  https://neo.loket.com/eticket/1577409681     XLUDWMQX
# 8995  https://neo.loket.com/eticket/1577409839     XLUD8BUB
# 8996  https://neo.loket.com/eticket/1577409963     XLUCJCQJ
# 8997  https://neo.loket.com/eticket/1577410945     XLUAIRCT
# 8999  https://neo.loket.com/eticket/1577413764     XLUGXBIH
#
#      status_invoice_name      invoice_expired         invoice_date  \
# 8994                PAID  2022-09-17 10:18:41  2022-09-17 10:03:21
# 8995                PAID  2022-09-17 10:20:35  2022-09-17 10:05:21
# 8996                PAID  2022-09-17 10:28:32  2022-09-17 10:13:18
# 8997                PAID  2022-09-17 12:00:20  2022-09-17 10:59:55
# 8999                PAID  2022-09-17 15:19:09  2022-09-17 15:03:50
#
#      voucher_status settlement_paid_timestamp         payment_name  \
# 8994          false       2022-09-17 10:03:57               GO-PAY
# 8995          false       2022-09-17 10:07:50  Credit / Debit Card
# 8996          false       2022-09-17 10:14:34  Credit / Debit Card
# 8997          false       2022-09-17 11:01:21  Virtual Account BCA
# 8999          false       2022-09-17 15:04:33               GO-PAY
#
#       invoice_payment_total  id_event status_invoice
# 8994                1712813     82424              5
# 8995                1449575     82424              5
# 8996                1449575     82424              5
# 8997                 290000     82424              5
# 8999                 144638     82424              5

# %%
all = get_all_bolafy_trx()

# %%
all.head()
# Out:
#    id user_id          id_order  \
# 0   4       1  72755MARXOBTJWCP
# 1   5      12  72755MARXOBRVHLE
# 2   8      11  72755MARXOBREHX1
# 3   9      10  72755MARXOBNXWS8
# 4  13       1  72753MARXOCWABZE
#
#                                         evoucher_url  \
# 0  https://neo.loket.com/evoucher/2d95ebde-e7ea-4...
# 1  https://neo.loket.com/evoucher/c1340c59-cd0b-4...
# 2  https://neo.loket.com/evoucher/17492bb1-bdf2-4...
# 3  https://neo.loket.com/evoucher/7c819c0e-108a-4...
# 4  https://neo.loket.com/evoucher/a09c0310-1b3c-4...
#
#                                 eticket_url invoice_code status_invoice_name  \
# 0  https://neo.loket.com/eticket/1569921476     XOBTJWCP                PAID
# 1  https://neo.loket.com/eticket/1569921574     XOBRVHLE                PAID
# 2  https://neo.loket.com/eticket/1569921602     XOBREHX1                PAID
# 3  https://neo.loket.com/eticket/1569921832     XOBNXWS8                PAID
# 4  https://neo.loket.com/eticket/1569931759     XOCWABZE                PAID
#
#        invoice_expired         invoice_date voucher_status  \
# 0  2022-03-03 16:57:15  2022-03-03 16:42:02          false
# 1  2022-03-03 17:30:28  2022-03-03 17:15:13          false
# 2  2022-03-03 20:26:16  2022-03-03 17:26:05          false
# 3  2022-03-03 21:47:21  2022-03-03 18:46:52          false
# 4  2022-03-05 09:38:25  2022-03-05 09:23:05          false
#
#   settlement_paid_timestamp         payment_name  invoice_payment_total  \
# 0       2022-03-03 16:42:28               GO-PAY                  50750
# 1       2022-03-03 17:15:56               GO-PAY                  25375
# 2       2022-03-03 17:29:13  Virtual Account BCA                  30000
# 3       2022-03-03 18:50:05  Virtual Account BCA                  55000
# 4       2022-03-05 09:23:44               GO-PAY                  76125
#
#    id_event status_invoice
# 0     72755           null
# 1     72755           null
# 2     72755           null
# 3     72755           null
# 4     72753              5

# %%
trx = get_table('transactions')

# %%
trx.tail(5)
# Out:
#         id user_id                  id_order  \
# 8675  8682   13778          82185SEPXLQ5O4EA
# 8676  8683   16945          81840SEPXLQ6DSCZ
# 8677  8684   13486          81385SEPXLQ6RLXI
# 8678  8664       4  MOFLIP-REDEEM-40M6F9SAQL
# 8679  8665       4  MOFLIP-REDEEM-Y9592WTOI8
#
#                                            evoucher_url  \
# 8675  https://neo.loket.com/evoucher/c95f89c2-9980-4...
# 8676  https://neo.loket.com/evoucher/f2e63b28-6b3d-4...
# 8677  https://neo.loket.com/evoucher/156357ff-866e-4...
# 8678                                https://bolafy.com/
# 8679                                https://bolafy.com/
#
#                                    eticket_url       invoice_code  \
# 8675  https://neo.loket.com/eticket/1577110300           XLQ5O4EA
# 8676  https://neo.loket.com/eticket/1577110980           XLQ6DSCZ
# 8677  https://neo.loket.com/eticket/1577111380           XLQ6RLXI
# 8678                       https://bolafy.com/  196488-X8Y1RCBL1L
# 8679                       https://bolafy.com/  196488-QQV289RYUI
#
#      status_invoice_name      invoice_expired         invoice_date  \
# 8675                PAID  2022-09-13 14:20:34  2022-09-13 14:05:09
# 8676                PAID  2022-09-13 14:41:55  2022-09-13 14:20:25
# 8677                PAID  2022-09-13 14:44:55  2022-09-13 14:29:26
# 8678                PAID  2022-09-12 16:06:08  2022-09-12 16:06:08
# 8679                PAID  2022-09-12 16:06:08  2022-09-12 16:06:08
#
#      voucher_status settlement_paid_timestamp payment_name  \
# 8675          false       2022-09-13 14:05:55       GO-PAY
# 8676          false       2022-09-13 14:28:00       GO-PAY
# 8677          false       2022-09-13 14:30:09       GO-PAY
# 8678          false       2022-09-12 16:06:08       Moflip
# 8679          false       2022-09-12 16:06:08       Moflip
#
#      invoice_payment_total id_event status_invoice
# 8675                 53288    82185              5
# 8676                 50750    81840              5
# 8677                 27913    81385              5
# 8678                  null    81435              5
# 8679                  null    81435              5

# %%
mev = get_table('moflip_ticket')

# %%
mev.tail()
# Out:
#     id_ticket event_id       ticket_type  \
# 493    199257    82225       Fadil Sausu
# 494    199258    82225     Beckham Putra
# 495    199259    82225        Hugo Gomez
# 496    199260    82225      Yakob Sayuri
# 497    199261    82225  Riyan Ardiansyah
#
#                                        description  \
# 493  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 494  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 495  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 496  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 497  Koleksi Digital Best XI: BRI Liga 1 2022/2023
#
#                                             start_sale  \
# 493  Tue Sep 13 2022 00:00:00 GMT+0000 (Coordinated...
# 494  Tue Sep 13 2022 00:00:00 GMT+0000 (Coordinated...
# 495  Tue Sep 13 2022 00:00:00 GMT+0000 (Coordinated...
# 496  Tue Sep 13 2022 00:00:00 GMT+0000 (Coordinated...
# 497  Tue Sep 13 2022 00:00:00 GMT+0000 (Coordinated...
#
#                                               end_sale  price quantity  \
# 493  Wed Sep 21 2022 00:00:00 GMT+0000 (Coordinated...  75000      100
# 494  Wed Sep 21 2022 00:00:00 GMT+0000 (Coordinated...  75000      100
# 495  Wed Sep 21 2022 00:00:00 GMT+0000 (Coordinated...  75000      100
# 496  Wed Sep 21 2022 00:00:00 GMT+0000 (Coordinated...  75000      100
# 497  Wed Sep 21 2022 00:00:00 GMT+0000 (Coordinated...  75000      100
#
#     available_qty available  ... fanPoint rarity is_popular evoucher_show  \
# 493           100      true  ...       60   Rare      false         false
# 494           100      true  ...       60   Rare      false         false
# 495           100      true  ...       60   Rare      false         false
# 496           100      true  ...       60   Rare      false         false
# 497           100      true  ...       60   Rare      false         false
#
#     ticket_category required_temp required status face_image_gallery  \
# 493             nft          null     null   null               null
# 494             nft          null     null   null               null
# 495             nft          null     null   null               null
# 496             nft          null     null   null               null
# 497             nft          null     null   null               null
#
#     required.bms
# 493         null
# 494         null
# 495         null
# 496         null
# 497         null
#
# [5 rows x 23 columns]

# %%
sales_by_id_event = all_trx.groupby('id_event')

# %%
sales_by_id_event = weekly_sales.groupby('id_event').sum('id_event')
all_id_event = list(sales_by_id_event.index)
sales_by_id_event = sales_by_id_event.to_dict()

# Load moflip ticket table and 
moflip_ticket_table = get_table('moflip_ticket').astype({
    'event_id':'int'
})
mask = (moflip_ticket_table['event_id'].isin(all_id_event))
moflip_ticket_table = moflip_ticket_table.loc[mask]

gk = moflip_ticket_table.groupby('event_id') # Group by event id
event_id_name = gk.first()['description'].to_dict()

event_name_sales_dict = {}

print(sales_by_id_event)

for id_event in all_id_event:
    event_name_sales_dict[event_id_name[id_event]] = (sales_by_id_event['invoice_payment_total'][id_event])
# Out:
# {'invoice_payment_total': {79594: 77100, 81385: 27913, 81840: 50750, 82185: 53288}}

# %%
event_name_sales_dict
# Out:
# {'Persikabo 1973 vs PERSIJA Jakarta': 77100,
#  'Momen Eksklusif Borneo FC: Kilas Balik Week 1 - 7': 27913,
#  'PERSIJA Jakarta vs Bhayangkara FC': 50750,
#  'PS Barito Putera vs PERSIJA Jakarta': 53288}

# %%
mev.loc[mev['event_id'] == '81435']
# Out:
#     id_ticket event_id           ticket_type  \
# 425    196482    81435   Andritany Ardhiyasa
# 427    196483    81435  Putu Gede Juniantara
# 428    196491    81435          Matheus Pato
# 429    196459    81435         Privat Mbarga
# 444    196484    81435           Rizky Ridho
# 445    196485    81435      Tallysson Duarte
# 446    196486    81435          Ricky Fajrin
# 447    196487    81435         Jayus Hariono
# 448    196488    81435    Marselino Ferdinan
# 449    196489    81435      Alexis Messidoro
# 450    196490    81435         Terens Puhiri
#
#                                        description  \
# 425  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 427  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 428  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 429  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 444  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 445  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 446  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 447  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 448  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 449  Koleksi Digital Best XI: BRI Liga 1 2022/2023
# 450  Koleksi Digital Best XI: BRI Liga 1 2022/2023
#
#                                             start_sale  \
# 425  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 427  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 428  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 429  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 444  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 445  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 446  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 447  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 448  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 449  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
# 450  Fri Aug 26 2022 00:00:00 GMT+0000 (Coordinated...
#
#                                               end_sale   price quantity  \
# 425  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 427  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 428  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 429  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...  249000       10
# 444  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 445  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 446  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 447  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 448  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 449  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
# 450  Sat Sep 03 2022 00:00:00 GMT+0000 (Coordinated...   75000      100
#
#     available_qty available  ... fanPoint      rarity is_popular  \
# 425           100      true  ...       60        Rare      false
# 427           100      true  ...       60        Rare      false
# 428           100      true  ...       60        Rare      false
# 429            10      true  ...      200  Super Rare      false
# 444           100      true  ...       60        Rare      false
# 445           100      true  ...       60        Rare      false
# 446           100      true  ...       60        Rare      false
# 447           100      true  ...       60        Rare      false
# 448           100      true  ...       60        Rare      false
# 449           100      true  ...       60        Rare      false
# 450           100      true  ...       60        Rare      false
#
#     evoucher_show ticket_category required_temp required status  \
# 425         false             nft          null     null   null
# 427         false             nft          null     null   null
# 428         false             nft          null     null   null
# 429         false             nft          null     null   null
# 444         false             nft          null     null   null
# 445         false             nft          null     null   null
# 446         false             nft          null     null   null
# 447         false             nft          null     null   null
# 448         false             nft          null     null   null
# 449         false             nft          null     null   null
# 450         false             nft          null     null   null
#
#     face_image_gallery required.bms
# 425               null         null
# 427               null         null
# 428               null         null
# 429               null         null
# 444               null         null
# 445               null         null
# 446               null         null
# 447               null         null
# 448               null         null
# 449               null         null
# 450               null         null
#
# [11 rows x 23 columns]

# %%
t = get_table('tickets')

# %%
t.tail(5)
# Out:
#         id id_ticket user_id txns_id ticket_quantity ticket_price  \
# 9086  9093    199116   13778    8682               1        50000
# 9087  9094    198003   16945    8683               1        50000
# 9088  9095    196301   13486    8684               1        25000
# 9089  9074    196488       4    8664               1            0
# 9090  9075    196488       4    8665               1            0
#
#                                    ticket_type nft_image payment_name  \
# 9086        The Goal Machine: Michael Krmencik                 GO-PAY
# 9087      Konsisten: Empat Kemenangan Beruntun                 GO-PAY
# 9088  Tendangan Bebas Mematikan : Matheus Pato                 GO-PAY
# 9089                        Marselino Ferdinan                 Moflip
# 9090                        Marselino Ferdinan                 Moflip
#
#      status_invoice_name id_event organization_id           barcode
# 9086                PAID    82185            null  8218536436317221
# 9087                PAID    81840            null  8184002181167869
# 9088                PAID    81385            null  8138557693039876
# 9089                PAID    81435            null          57590008
# 9090                PAID    81435            null          75430197

# %%
nft = get_table('nft')

# %%
nft.sample(3)
# Out:
#           id ticket_id ticket_counter preview nft_images  \
# 13953  14234      9214              1    null       null
# 12608  12794      7855              1    null       null
# 6178    4685      2304              1    null       null
#
#                                  contract_address ipfs_hash  \
# 13953                                        null      null
# 12608  0x2953399124f0cbb46d2cbacd8a89cf0599974963      null
# 6178   0x6143db544535e6cdc78669ca4499b016dab0ff55      null
#
#                                            open_sea_link user_id  \
# 13953                                               null    null
# 12608  https://opensea.io/assets/matic/0x2953399124f0...   11867
# 6178   https://opensea.io/assets/matic/0x6143db544535...    5360
#
#       original_owner_id  ...                                title  \
# 13953              null  ...
# 12608             11867  ...  PERSIJA Jakarta vs PERSIS Solo #057
# 6178               5360  ...              Baladewa Festival #1428
#
#                                              description moflip_ticket_origin  \
# 13953                                                                    null
# 12608  Koleksi Tiket NFT - PERSIJA Jakarta vs PERSIS ...                 null
# 6178   Selamat, Anda adalah pemegang Baladewa 30 Fest...                 null
#
#                 barcode                                       evoucher_url  \
# 13953          93907435                                https://bolafy.com/
# 12608  7959403435339866  https://neo.loket.com/evoucher/3b008c8b-4e0f-4...
# 6178   7595107745298604  https://neo.loket.com/evoucher/9aac33a3-400f-4...
#
#         rarity owner_name owner_company redeem_code eticket_url
# 13953     Rare       null          null  MC93907435        null
# 12608  Limited       null          null        null        null
# 6178    Common       null          null        null        null
#
# [3 rows x 23 columns]
